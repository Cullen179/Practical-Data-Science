# %%
import pandas as pd

# %%
df = pd.DataFrame([[1,2, 3], [4,5, 6], [4, 5, 6]], columns=['A', 'B', 'C'], index=['a', 'b', 'c'])

# %%
df.head()
# Out:
#    A  B  C
# a  1  2  3
# b  4  5  6
# c  4  5  6

# %%
coffee = pd.read_csv('./complete-pandas-tutorial/warmup-data/coffee.csv')

# %%
bios = pd.read_csv('./complete-pandas-tutorial/data/bios.csv')

# %%
results = pd.read_parquet('./complete-pandas-tutorial/data/results.parquet', engine='fastparquet')

# %%
results
# Out:
#           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                    None        Slalom, Women (Olympic)
#
#                            as  athlete_id   noc             team  place  \
# 0       Jean-François Blanchy           1   FRA             None   17.0
# 1       Jean-François Blanchy           1   FRA   Jean Montariol    NaN
# 2       Jean-François Blanchy           1   FRA             None   32.0
# 3       Jean-François Blanchy           1   FRA  Jeanne Vaussard    8.0
# 4       Jean-François Blanchy           1   FRA  Jacques Brugnon    4.0
# ...                       ...         ...   ...              ...    ...
# 308403          Marián Skupek      148983   SVK             None   26.0
# 308404          Elsa Fermbäck      148984   SWE             None   28.0
# 308405          Hilma Lövblom      148985   SWE           Sweden   13.0
# 308406          Hilma Lövblom      148985   SWE             None    NaN
# 308407   Charlotta Säfvenberg      148986  None             None   24.0
#
#          tied medal
# 0        True  None
# 1       False  None
# 2        True  None
# 3        True  None
# 4       False  None
# ...       ...   ...
# 308403  False  None
# 308404  False  None
# 308405  False  None
# 308406  False  None
# 308407  False  None
#
# [308408 rows x 11 columns]

# %%
olympics_data = pd.read_excel('./complete-pandas-tutorial/data/olympics-data.xlsx', sheet_name='results')

# %%
olympics_data
# Out:
#           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                     NaN        Slalom, Women (Olympic)
#
#                            as  athlete_id  noc             team  place   tied  \
# 0       Jean-François Blanchy           1  FRA              NaN   17.0   True
# 1       Jean-François Blanchy           1  FRA   Jean Montariol    NaN  False
# 2       Jean-François Blanchy           1  FRA              NaN   32.0   True
# 3       Jean-François Blanchy           1  FRA  Jeanne Vaussard    8.0   True
# 4       Jean-François Blanchy           1  FRA  Jacques Brugnon    4.0  False
# ...                       ...         ...  ...              ...    ...    ...
# 308403          Marián Skupek      148983  SVK              NaN   26.0  False
# 308404          Elsa Fermbäck      148984  SWE              NaN   28.0  False
# 308405          Hilma Lövblom      148985  SWE           Sweden   13.0  False
# 308406          Hilma Lövblom      148985  SWE              NaN    NaN  False
# 308407   Charlotta Säfvenberg      148986  NaN              NaN   24.0  False
#
#        medal
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 308403   NaN
# 308404   NaN
# 308405   NaN
# 308406   NaN
# 308407   NaN
#
# [308408 rows x 11 columns]

# %%
display(coffee)
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.loc[0:, ["Day"]]
# Out:
#           Day
# 0      Monday
# 1      Monday
# 2     Tuesday
# 3     Tuesday
# 4   Wednesday
# 5   Wednesday
# 6    Thursday
# 7    Thursday
# 8      Friday
# 9      Friday
# 10   Saturday
# 11   Saturday
# 12     Sunday
# 13     Sunday

# %%
coffee.sort_values(['Day', 'Coffee Type'], ascending=False)
# Out:
#           Day Coffee Type  Units Sold
# 5   Wednesday       Latte          25
# 4   Wednesday    Espresso          35
# 3     Tuesday       Latte          20
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 6    Thursday    Espresso          40
# 13     Sunday       Latte          35
# 12     Sunday    Espresso          45
# 11   Saturday       Latte          35
# 10   Saturday    Espresso          45
# 1      Monday       Latte          15
# 0      Monday    Espresso          25
# 9      Friday       Latte          35
# 8      Friday    Espresso          45

# %%
bios.loc[bios['height_cm'] > 215]
# Out:
#         athlete_id                   name   born_date               born_city  \
# 5089          5108     Viktor Pankrashkin  1957-06-19         Moskva (Moscow)
# 5583          5606   Paulinho Villas Boas  1963-01-26               São Paulo
# 5673          5696         Gunther Behnke  1963-01-19              Leverkusen
# 5716          5739               Uwe Blab  1962-03-26        München (Munich)
# 5781          5804         Tommy Burleson  1952-02-24               Crossnore
# 5796          5819          Andy Campbell  1956-07-21               Melbourne
# 6223          6250            Lars Hansen  1954-09-27  København (Copenhagen)
# 6270          6298            Hu Zhangbao  1963-04-05                     NaN
# 6409          6440       Sergey Kovalenko  1947-08-11                     NaN
# 6420          6451          Jānis Krūmiņš  1930-01-30                   Cēsis
# 6504          6537            Luc Longley  1969-01-19               Melbourne
# 6722          6755       Shaquille O'Neal  1972-03-06                  Newark
# 6937          6972         David Robinson  1965-08-06                Key West
# 6978          7013        Arvydas Sabonis  1964-12-19                  Kaunas
# 7074          7111         Paulo da Silva  1963-07-21               São Paulo
# 7188          7226     Vladimir Tkachenko  1957-09-20               Golovinka
# 7281          7320       Stojko Vranković  1964-01-22                   Drniš
# 7376          7416    Eurelijus Žukauskas  1973-08-22                Klaipėda
# 52608        52983        Aleksey Kazakov  1976-03-18      Naberezhnye Chelny
# 82100        82753          Frédéric Weis  1977-06-22              Thionville
# 89070        89782               Yao Ming  1980-09-12          Xuhui District
# 89075        89787         Roberto Dueñas  1975-11-01                  Madrid
# 107408      108533       Peter John Ramos  1985-05-23                 Fajardo
# 112312      113568           Stanko Barać  1986-08-13                  Mostar
# 112332      113588    Andreas Glyniadakis  1981-08-26                  Chania
# 112337      113593          Hamed Haddadi  1985-05-19                   Ahvaz
# 118663      120400         Timofey Mozgov  1986-07-16                     NaN
# 118676      120415        Dmitry Musersky  1988-10-29                Makiïvka
# 120266      122147           Zhang Zhaoxu  1987-11-18                 Binzhou
# 121694      123709            Salah Mejri  1986-06-15                Jendouba
# 123850      126093         Tyson Chandler  1982-10-02                 Hanford
# 130460      133147               Li Muhao  1992-06-02                 Guiyang
# 130461      133148                Zhou Qi  1996-01-16                Xinxiang
# 138671      142084          Ondřej Balvín  1992-09-20          Ústí nad Labem
# 139365      142836         Moustapha Fall  1992-02-23                   Paris
#
#                             born_region born_country  \
# 5089                             Moskva          RUS
# 5583                          São Paulo          BRA
# 5673                Nordrhein-Westfalen          GER
# 5716                             Bayern          GER
# 5781                     North Carolina          USA
# 5796                           Victoria          AUS
# 6223                        Hovedstaden          DEN
# 6270                                NaN          NaN
# 6409                                NaN          NaN
# 6420                        Cēsu novads          LAT
# 6504                           Victoria          AUS
# 6722                         New Jersey          USA
# 6937                            Florida          USA
# 6978                             Kaunas          LTU
# 7074                          São Paulo          BRA
# 7188                     Krasnodar Kray          RUS
# 7281          Šibensko-kninska županija          CRO
# 7376                           Klaipėda          LTU
# 52608              Respublika Tatarstan          RUS
# 82100                           Moselle          FRA
# 89070                          Shanghai          CHN
# 89075                            Madrid          ESP
# 107408                      Puerto Rico          PUR
# 112312  Hercegovačko-neretvanski kanton          BIH
# 112332                            Kriti          GRE
# 112337                        Khuzestan          IRI
# 118663                              NaN          NaN
# 118676                          Donetsk          UKR
# 120266                         Shandong          CHN
# 121694                         Jendouba          TUN
# 123850                       California          USA
# 130460                          Guizhou          CHN
# 130461                            Henan          CHN
# 138671                     Ústecký kraj          CZE
# 139365                            Paris          FRA
#
#                                NOC  height_cm  weight_kg   died_date
# 5089                  Soviet Union      220.0      112.0  1993-07-24
# 5583                        Brazil      217.0      106.0         NaN
# 5673                       Germany      221.0      114.0         NaN
# 5716          Germany West Germany      218.0      110.0         NaN
# 5781                 United States      223.0      102.0         NaN
# 5796                     Australia      218.0       93.0         NaN
# 6223                        Canada      216.0      105.0         NaN
# 6270    People's Republic of China      216.0      135.0         NaN
# 6409                  Soviet Union      216.0      111.0  2004-11-18
# 6420                  Soviet Union      218.0      141.0  1994-11-20
# 6504                     Australia      220.0      135.0         NaN
# 6722                 United States      216.0      137.0         NaN
# 6937                 United States      216.0      107.0         NaN
# 6978        Lithuania Soviet Union      223.0      122.0         NaN
# 7074                        Brazil      217.0      106.0         NaN
# 7188                  Soviet Union      220.0      110.0         NaN
# 7281            Croatia Yugoslavia      217.0      115.0         NaN
# 7376                     Lithuania      218.0      115.0         NaN
# 52608           Russian Federation      217.0      102.0         NaN
# 82100                       France      218.0      110.0         NaN
# 89070   People's Republic of China      226.0      141.0         NaN
# 89075                        Spain      221.0      137.0         NaN
# 107408                 Puerto Rico      219.0      113.0         NaN
# 112312                     Croatia      217.0      110.0         NaN
# 112332                      Greece      216.0      115.0         NaN
# 112337    Islamic Republic of Iran      218.0      110.0         NaN
# 118663          Russian Federation      216.0      113.0         NaN
# 118676          Russian Federation      219.0      104.0         NaN
# 120266  People's Republic of China      221.0      110.0         NaN
# 121694                     Tunisia      216.0      110.0         NaN
# 123850               United States      216.0      107.0         NaN
# 130460  People's Republic of China      218.0      115.0         NaN
# 130461  People's Republic of China      217.0       95.0         NaN
# 138671                     Czechia      216.0      107.0         NaN
# 139365                      France      218.0        NaN         NaN

# %%
bios[bios['born_country'].isin(['USA'])]
# Out:
#         athlete_id               name   born_date         born_city  \
# 54              55      Monique Javer  1967-07-22        Burlingame
# 960            964   Xóchitl Escobedo  1968-09-17       West Covina
# 961            965  Angélica Gavaldón  1973-10-03         El Centro
# 1231          1238     Bert Schneider  1897-07-01         Cleveland
# 1345          1352         Laura Berg  1975-01-06  Santa Fe Springs
# ...            ...                ...         ...               ...
# 145445      149168     Kristen Santos  1994-11-02         Fairfield
# 145446      149169   Corinne Stoddard  2001-08-15           Seattle
# 145454      149180      Anna Hoffmann  2000-03-28           Madison
# 145457      149183     Alix Wilkinson  2000-08-02     Mammoth Lakes
# 145468      149195  Justin Abdelkader  1987-02-25          Muskegon
#
#         born_region born_country            NOC  height_cm  weight_kg  \
# 54       California          USA  Great Britain      177.0       64.0
# 960      California          USA         Mexico      170.0       60.0
# 961      California          USA         Mexico      160.0       54.0
# 1231           Ohio          USA         Canada        NaN        NaN
# 1345     California          USA  United States      168.0       61.0
# ...             ...          ...            ...        ...        ...
# 145445  Connecticut          USA  United States        NaN        NaN
# 145446   Washington          USA  United States        NaN        NaN
# 145454    Wisconsin          USA  United States        NaN        NaN
# 145457   California          USA  United States        NaN        NaN
# 145468     Michigan          USA  United States      187.0       97.0
#
#          died_date
# 54             NaN
# 960            NaN
# 961            NaN
# 1231    1986-02-20
# 1345           NaN
# ...            ...
# 145445         NaN
# 145446         NaN
# 145454         NaN
# 145457         NaN
# 145468         NaN
#
# [9641 rows x 10 columns]

# %%
coffee['price'] = 5

# %%
import numpy as np

coffee['new_price'] = np.where(coffee['Coffee Type'] == 'Espresso', 3, 6)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  new_price
# 0      Monday    Espresso          25      5          3
# 1      Monday       Latte          15      5          6
# 2     Tuesday    Espresso          30      5          3
# 3     Tuesday       Latte          20      5          6
# 4   Wednesday    Espresso          35      5          3
# 5   Wednesday       Latte          25      5          6
# 6    Thursday    Espresso          40      5          3
# 7    Thursday       Latte          30      5          6
# 8      Friday    Espresso          45      5          3
# 9      Friday       Latte          35      5          6
# 10   Saturday    Espresso          45      5          3
# 11   Saturday       Latte          35      5          6
# 12     Sunday    Espresso          45      5          3
# 13     Sunday       Latte          35      5          6

# %%
coffee.drop(columns=['price'], inplace=True)

# %%
test = coffee[['Day']]

test
# Out:
#           Day
# 0      Monday
# 1      Monday
# 2     Tuesday
# 3     Tuesday
# 4   Wednesday
# 5   Wednesday
# 6    Thursday
# 7    Thursday
# 8      Friday
# 9      Friday
# 10   Saturday
# 11   Saturday
# 12     Sunday
# 13     Sunday

# %%
bios['born_date'] = pd.to_datetime(bios['born_date'])

# %%
bios['born_date'].dt.day
# Out:
# 0         12.0
# 1          1.0
# 2         13.0
# 3         11.0
# 4         17.0
#           ...
# 145495    30.0
# 145496    20.0
# 145497     8.0
# 145498    19.0
# 145499    15.0
# Name: born_date, Length: 145500, dtype: float64

# %%
nocs = pd.read_csv('./complete-pandas-tutorial/data/noc_regions.csv')

# %%
nocs
# Out:
#      NOC       region                 notes
# 0    AFG  Afghanistan                   NaN
# 1    AHO      Curacao  Netherlands Antilles
# 2    ALB      Albania                   NaN
# 3    ALG      Algeria                   NaN
# 4    AND      Andorra                   NaN
# ..   ...          ...                   ...
# 225  YEM        Yemen                   NaN
# 226  YMD        Yemen           South Yemen
# 227  YUG       Serbia            Yugoslavia
# 228  ZAM       Zambia                   NaN
# 229  ZIM     Zimbabwe                   NaN
#
# [230 rows x 3 columns]

# %%
pd.merge(bios, nocs, left_on='born_country', right_on='NOC', how='inner')
# Out:
#         athlete_id                   name  born_date        born_city  \
# 0                1  Jean-François Blanchy 1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch 1969-04-01           Meulan
# 2                3           Jean Borotra 1898-08-13         Biarritz
# 3                4        Jacques Brugnon 1895-05-11      Paris VIIIe
# 4                5           Albert Canet 1878-04-17       Wandsworth
# ...            ...                    ...        ...              ...
# 110634      149222      Polina Luchnikova 2002-01-30            Serov
# 110635      149223    Valeriya Merkusheva 1999-09-20  Moskva (Moscow)
# 110636      149224        Yuliya Smirnova 1998-05-08           Kotlas
# 110637      149225         André Foussard 1899-05-19            Niort
# 110638      149814          Bill Phillips 1913-07-15     Dulwich Hill
#
#                  born_region born_country      NOC_x  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 110634            Sverdlovsk          RUS        ROC      167.0       61.0
# 110635                Moskva          RUS        ROC      168.0       65.0
# 110636           Arkhangelsk          RUS        ROC      163.0       55.0
# 110637           Deux-Sèvres          FRA     France      166.0        NaN
# 110638       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date NOC_y     region notes
# 0       1960-10-02   FRA     France   NaN
# 1              NaN   FRA     France   NaN
# 2       1994-07-17   FRA     France   NaN
# 3       1978-03-20   FRA     France   NaN
# 4       1930-07-25   GBR         UK   NaN
# ...            ...   ...        ...   ...
# 110634         NaN   RUS     Russia   NaN
# 110635         NaN   RUS     Russia   NaN
# 110636         NaN   RUS     Russia   NaN
# 110637  1986-03-18   FRA     France   NaN
# 110638  2003-10-20   AUS  Australia   NaN
#
# [110639 rows x 13 columns]

# %%
coffee.loc[[0, 2], 'Units Sold'] = np.nan

# %%
coffee.isna().sum()
# Out:
# Day            0
# Coffee Type    0
# Units Sold     2
# new_price      0
# dtype: int64

# %%
coffee['Units Sold'] = coffee['Units Sold'].interpolate()

# %%
coffee.dropna()
# Out:
#           Day Coffee Type  Units Sold  new_price
# 1      Monday       Latte       22.50          6
# 2     Tuesday    Espresso       21.25          3
# 3     Tuesday       Latte       20.00          6
# 4   Wednesday    Espresso       35.00          3
# 5   Wednesday       Latte       25.00          6
# 6    Thursday    Espresso       40.00          3
# 7    Thursday       Latte       30.00          6
# 8      Friday    Espresso       45.00          3
# 9      Friday       Latte       35.00          6
# 10   Saturday    Espresso       45.00          3
# 11   Saturday       Latte       35.00          6
# 12     Sunday    Espresso       45.00          3
# 13     Sunday       Latte       35.00          6

# %%
bios[bios['born_country'] == 'USA']['born_city'].value_counts().tail()
# Out:
# born_city
# Milpitas         1
# Chesterfield     1
# American Fork    1
# Cadyville        1
# Fair Haven       1
# Name: count, dtype: int64

# %%
coffee.groupby(['Coffee Type']).agg({
  'Units Sold': 'sum', 
  'new_price': 'mean'
})
# Out:
#              Units Sold  new_price
# Coffee Type
# Espresso         231.25        3.0
# Latte            202.50        6.0

# %%
pivot = coffee.pivot(columns='Coffee Type', index='Day', values='Units Sold')

# %%
pivot
# Out:
# Coffee Type  Espresso  Latte
# Day
# Friday          45.00   35.0
# Monday            NaN   22.5
# Saturday        45.00   35.0
# Sunday          45.00   35.0
# Thursday        40.00   30.0
# Tuesday         21.25   20.0
# Wednesday       35.00   25.0

# %%
bios['born_date'] = pd.to_datetime(bios['born_date'])

bios.groupby(bios['born_date'].dt.year)['name'].count().reset_index()
# Out:
#      born_date  name
# 0       1828.0     1
# 1       1831.0     2
# 2       1833.0     1
# 3       1836.0     1
# 4       1837.0     1
# ..         ...   ...
# 172     2005.0   163
# 173     2006.0    17
# 174     2007.0     3
# 175     2008.0     3
# 176     2009.0     1
#
# [177 rows x 2 columns]

# %%
coffee['revenue'] = coffee['Units Sold'] * coffee['new_price']

# %%
coffee['yesterday_rev'] = coffee['revenue'].shift(2)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price  revenue  yesterday_rev
# 0      Monday    Espresso         NaN          3      NaN            NaN
# 1      Monday       Latte       22.50          6   135.00            NaN
# 2     Tuesday    Espresso       21.25          3    63.75            NaN
# 3     Tuesday       Latte       20.00          6   120.00         135.00
# 4   Wednesday    Espresso       35.00          3   105.00          63.75
# 5   Wednesday       Latte       25.00          6   150.00         120.00
# 6    Thursday    Espresso       40.00          3   120.00         105.00
# 7    Thursday       Latte       30.00          6   180.00         150.00
# 8      Friday    Espresso       45.00          3   135.00         120.00
# 9      Friday       Latte       35.00          6   210.00         180.00
# 10   Saturday    Espresso       45.00          3   135.00         135.00
# 11   Saturday       Latte       35.00          6   210.00         210.00
# 12     Sunday    Espresso       45.00          3   135.00         135.00
# 13     Sunday       Latte       35.00          6   210.00         210.00
